# %% [markdown]
# # 04 - PhoBERT Topic Fine-tuning
#
# Fine-tune PhoBERT for topic classification if valid topic labels are available.
#
# This notebook is part of the staged NLP project workflow. Keep code simple, reproducible, and chart-oriented.

# %% [markdown]
# ## Checklist
#
# - [ ] Confirm inputs
# - [ ] Run analysis or experiment
# - [ ] Save tables to
# eports/tables/
# - [ ] Save figures to
# eports/figures/
# - [ ] Write short notes in English

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print('Project root:', PROJECT_ROOT)
